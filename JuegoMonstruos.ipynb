# %%
# %%capture
# %run juego/Juego.ipynb

# %%
class CorrerJuego ():
    if __name__ == "__main__":
        juego = Juego()
        juego.iniciar_juego()
# Out:
# 1- Crear Juego
# 2- Cargar Juego
# 3- Salir
# 1
# Ingrese el nombre del jugador 1: A
# Ingrese el numero de la tipologia que desea utilizar:
# 1- AGUA
# 2- AIRE
# 3- TIERRA
# 4- FUEGO
# 1
# Ingrese el numero de la tipologia que desea utilizar:
# 1- AGUA
# 2- AIRE
# 3- TIERRA
# 4- FUEGO
# 2
# Ingrese el nombre del jugador 2: B
# Ingrese el numero de la tipologia que desea utilizar:
# 1- AGUA
# 2- AIRE
# 3- TIERRA
# 4- FUEGO
# 1
# Ingrese el numero de la tipologia que desea utilizar:
# 1- AGUA
# 2- AIRE
# 3- TIERRA
# 4- FUEGO
# 2
#
# Turno del jugador 1
# 1- Ataque simple tipo: AGUA
# 2- Ataque especial tipo: AGUA
# 3- Ataque simple tipo: AIRE
# 4- Ataque especial tipo: AIRE
# 2
# El monstruo enemigo recibio 15 puntos de daño.
# El monstruo enemigo posee 85 puntos de vida
# ¿Desea guardar la partida? (S/N)n
#
# Turno del jugador 2
# 1- Ataque simple tipo: AGUA
# 2- Ataque especial tipo: AGUA
# 3- Ataque simple tipo: AIRE
# 4- Ataque especial tipo: AIRE
# 2
# ...
